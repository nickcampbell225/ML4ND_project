# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Nuclear_data.csv")

# %%
data
# Out:
#           Z    A     MT  E_in_MeV  dE_in_MeV      XS_b     dXS_b  \
# 0        66  161  102.0     0.143       0.12  0.195360  0.045560
# 1        66  161  102.0     0.143       0.12  0.459460  0.333720
# 2        66  161  102.0     0.263       0.12  0.124890  0.027598
# 3        66  161  102.0     0.263       0.12  0.324490  0.223600
# 4        66  161  102.0     0.383       0.12  0.081334  0.019615
# ...      ..  ...    ...       ...        ...       ...       ...
# 4815208  30   66   16.0    30.400       0.80  0.340000  0.050000
# 4815209  30   66   16.0    35.900       0.80  0.330000  0.050000
# 4815210  30   66   16.0    14.770       0.17  0.723510  0.085092
# 4815211  30   66   16.0    14.000       0.20  0.655600  0.033100
# 4815212  26   66  108.0    22.500      15.80  0.000030  0.000020
#
#          mass_excess_keV  binding_energy_per_A_keV  atomic_mass_micro_u  ...  \
# 0             -68055.494                 8173.3093         1.609269e+08  ...
# ...
